# %% [markdown]
# # CheckAtlas examples : Evaluate and compare different version of your atlas

# %% [markdown]
# In this example, we show how to run checkatlas in a folder where different version of the same atlas can be found. We thus reproduce the folder of every atlas currently analyzed. We use as a reference the Fetal Scanpy atlas downloaded in example 1, and create different version by filtering out cells and modifying <i>obsm</i> names.

# %% [markdown]
# WARNING: Install and run only MultiQC from https://github.com/becavin-lab/MultiQC/tree/checkatlas. Otherwise checkatlas files will not be taken into account.

# %% [markdown]
# ## Download datasets

# %% [markdown]
# IF not already done, download Fetal dataset

# %% [markdown]
# Fetal<br>
# From:
# <a href=https://cellxgene.cziscience.com/collections/13d1c580-4b17-4b2e-85c4-75b36917413f>Single cell derived mRNA signals across human kidney tumors - Young et al. (2021) Nat Commun</a>

# %%
# import os

# os.chdir("/data/analysis/data_becavin/checkatlas_test/tuto")
# print(os.getcwd())

# %%
# %%bash
# cd /home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_data/example_2
# curl -o Fetal.h5ad "https://corpora-data-prod.s3.amazonaws.com/5d80925e-efbe-46cd-b3a7-2033d0d85e12/local.h5ad?AWSAccessKeyId=ASIATLYQ5N5XUQSD5KVY&Signature=iSn9g8iNzQEHX730fLX%2FvjQOLZ8%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEDMaCXVzLXdlc3QtMiJGMEQCIGJgh1IUS9%2F2Nx7nLMdNyqgLtRYdQw8eOntcVMX951vEAiAEJZARKHeUvskhgcYc4avFvsMAavo6bjAMLpW6%2B2goLCr0Awjs%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAEaDDIzMTQyNjg0NjU3NSIMwI%2Fs91bo7p7ikphgKsgDC%2FMS6kQpqT%2FaUzo1sFkdUe4z6rW58xDI2bLP2jyK1qN53k7WDGOY6ZEY%2BWBIKbYdnyo6qX4rUGYI0HLWd70r6CuavjGupipFqWb%2FWUSslUit8yuUGmRG9VfBjPdN3BxLH7VN92hk94IvIDKs1JjqD%2FcN1DghEhIF1jdqxur4oUemJlcSGFSCZsuA4Jt%2ByIIqJFbDpAY1DGOoBkIU6TEE7U7JFKS6tbyzD2BxdK1xJ250ngAW69%2BSztJ5zlJGUZdGdOj7rxPS5BdnscqFm3wol0NMyRXUOlfPov6ZDwD4ZEJ%2Be3YfmkFBPo76XAgHzFfOnrZxUO%2FHgFa%2BhOS5OVPdq3Ja84rQWCuLmcWCGIXJKYc6Gxq7cCn6hS3Es06cETMHQ5r50hzCa4X6%2BABSlOqFjKorLtrN4qbvKYVC90iQK%2FrsISyd8un1xolDTv8XSNV3cylMHViOZ%2FsXLs%2BQ0exEnhNWOTeGXNjU6t2AU7R6GM0Ujg1mhg3VQs%2F4xn0zfL3XYGBMS5YVz39EiZHmoRtWP%2FbDtGHPLyoMF%2Fi8Ds1a6eC0kChRLAPFaxKiqLZMzXjxX243sxgJAGXNQ2wX2GnJ1orbMRCLpaGjMJPQxqAGOqYBRko7GITv8QWheRct2rya9MQfQwVfS5r3%2FGra7bFiprdvWcPqxW4va%2F6gx37Q7OahyEEDg9%2FFlGDdhQuP4jRT6AaoeufeDaK2b2ENpFQ7DR%2BEOrpUm6y63YPA%2BccfZlEwfESPRGDJBDFswULs2ks8u9TOxIb5Gr9DBC5Sy8NrrBabZzwZr40s%2B3pk4W%2Br4fHfx6m6gpvgPh1LBE1K0QbgGK9smWyTwQ%3D%3D&Expires=1679501034"

# %% [markdown]
# Create different version to mimic currently analyzed atlas folder.

# %%
# %%bash
# cd /home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_data/example_2
# mkdir -p data2/
# mkdir -p data2/V1
# mkdir -p data2/V2
# mkdir -p data2/V3

# %%
import scanpy as sc

adata = sc.read_h5ad("/home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_data/example_0_1/Fetal.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 27203 × 32828
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'donor_id', 'Stage', 'Selection', 'compartment', 'age', 'CnT', 'DTLH', 'UBCD', 'SSBpr', 'End', 'MSC', 'RVCSB', 'SSBpod', 'SSBm.d', 'ICa', 'ErPrT', 'ICb', 'NPC', 'Pod', 'annotCell', 'author_cell_type', 'cell_type_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'assay_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'schema_version', 'title'
#     obsm: 'X_pca', 'X_umap'

# %%
# V1 is 2/3 of cells with new umap
adata_v1 = sc.pp.subsample(adata, fraction=0.6, copy=True)
sc.tl.pca(adata_v1, svd_solver="arpack")
sc.pp.neighbors(adata_v1, n_pcs=30, n_neighbors=20)
sc.tl.umap(adata_v1)
adata_v1.write("/home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_data/example_2/data2/V1/Fetal_v1.h5ad")
adata_v1
# Out:
# AnnData object with n_obs × n_vars = 16321 × 32828
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'donor_id', 'Stage', 'Selection', 'compartment', 'age', 'CnT', 'DTLH', 'UBCD', 'SSBpr', 'End', 'MSC', 'RVCSB', 'SSBpod', 'SSBm.d', 'ICa', 'ErPrT', 'ICb', 'NPC', 'Pod', 'annotCell', 'author_cell_type', 'cell_type_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'assay_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'schema_version', 'title', 'pca', 'neighbors', 'umap'
# ...

# %%
# V2 is Fetal without raw data
adata_v2 = adata.copy()
adata_v2.raw = None
adata_v2.write("/home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_data/example_2/data2/V2/Fetal_v2.h5ad")
adata_v2
# Out:
# AnnData object with n_obs × n_vars = 27203 × 32828
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'donor_id', 'Stage', 'Selection', 'compartment', 'age', 'CnT', 'DTLH', 'UBCD', 'SSBpr', 'End', 'MSC', 'RVCSB', 'SSBpod', 'SSBm.d', 'ICa', 'ErPrT', 'ICb', 'NPC', 'Pod', 'annotCell', 'author_cell_type', 'cell_type_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'assay_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'schema_version', 'title'
#     obsm: 'X_pca', 'X_umap'

# %%
# V3 is Fetal without cell_type annotation
adata_v3 = adata.copy()
del adata_v3.obs["author_cell_type"]
del adata_v3.obs["cell_type"]
del adata_v3.obs["cell_type_ontology_term_id"]
adata_v3.write("/home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_data/example_2/data2/V3/Fetal_v3.h5ad")
adata_v3
# Out:
# AnnData object with n_obs × n_vars = 27203 × 32828
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'donor_id', 'Stage', 'Selection', 'compartment', 'age', 'CnT', 'DTLH', 'UBCD', 'SSBpr', 'End', 'MSC', 'RVCSB', 'SSBpod', 'SSBm.d', 'ICa', 'ErPrT', 'ICb', 'NPC', 'Pod', 'annotCell', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'organism_ontology_term_id', 'is_primary_data', 'assay_ontology_term_id', 'suspension_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'schema_version', 'title'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ## Run checkatlas

# %% [markdown]
# If checkatlas is installed in your environment, you just need to run this cell. This will produce all metric tables and figures needed.

# %%
# Set environment variable to use conda's C++ library
import os
os.environ['LD_LIBRARY_PATH'] = f"/home/bernadettem/anaconda3/envs/ritwik_base/lib:{os.environ.get('LD_LIBRARY_PATH', '')}"

# Verify the library path
print(f"LD_LIBRARY_PATH set to: {os.environ['LD_LIBRARY_PATH']}")
# Out:
# LD_LIBRARY_PATH set to: /home/bernadettem/anaconda3/envs/ritwik_base/lib:/usr/local/cuda-12.8/lib64:/usr/local/cuda-12.8/lib64:

# %%
# %%bash
# nextflow run nf-core-checkatlas -r dev --path /data/analysis/data_becavin/checkatlas_test/tuto/data2/

# %%
# %%bash
# nextflow run /home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/checkatlas/main.nf \
#   --path /home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_data/example_2/data2 \
#   --outdir /home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/atlas_output_result/example_2
# Out:
# Nextflow 25.04.8 is available - Please consider updating your version to it
#  N E X T F L O W   ~  version 24.04.4
#
# Launching `/home/bernadettem/bernadettenotebook/Ritwik/checkatlas_project/checkatlas/main.nf` [jolly_poisson] DSL2 - revision: 18983e6352
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# o.     O .oOo            .oOOOo.   o                o                   o
# Oo     o O              .O     o  O                 O                  O
# O O    O o              o         o                 o              O   o
# O  o   o OoO            o         O                 o             oOo  O
# O   o  O o    ooooooooo o         OoOo. .oOo. .oOo  O  o  .oOoO'   o   o  .oOoO' .oOo
# o    O O O              O         o   o OooO' O     OoO   O   o    O   O  O   o  `Ooo.
# o     Oo o              `o     .o o   O O     o     o  O  o   O    o   o  o   O      O
# ...

# %% [markdown]
# ## Open MultiQC report

# %% [markdown]
# Once checkatlas has been run, all tables and fig and html reports can be found in the checkatlas_files folder.
# **The MultiQC html summary files is in checkatlas_files/Checkatlas_MultiQC.html**

# %%
from IPython.display import IFrame

IFrame(
    src="data2/checkatlas_files/Checkatlas_MultiQC.html",
    width="100%",
    height="500px",
)
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="data2/checkatlas_files/Checkatlas_MultiQC.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
