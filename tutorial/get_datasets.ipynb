# %% [markdown]
# # Notebook for downloading datasets

# %%
# ## List of datasets
# # Load excel file

# # Get .h5ad link

# # Download dataset using .h5ad link
# curl -O https://example.com/dataset.h5ad


# # rename and organize datasets


# # Run checkatlas for each datasets
# checkatlas --dataset_path   for all metrics (python version)
# # timer
# time.time()

# multiqc_data/


# # Create the report
# multiqc .

# %%
import pandas as pd
import scanpy as sc

# %%
df = pd.read_excel("/home/ganguly/checkatlas/tutorial/List-datasets-2026.xlsx")
df
# Out:
#                                              Dataset Organism       Tissue  \
# 0      Human CellCards Multi-Study CellRef 1.0 Atlas    Human         lung
# 1  An integrated cell atlas of the human lung in ...    Human    4 tissues
# 2                            Tabula Sapiens - Immune    Human   74 tissues
# 3                            Tabula Sapiens - Neural    Human   16 tissues
# 4                             Tabula Sapiens - Blood    Human        blood
# 5                       Tabula Sapiens - Bone_Marrow    Human  bone marrow
# 6                             Tabula Sapiens - Liver    Human        liver
# 7                              Tabula Sapiens - Skin    Human    4 tissues
# 8  Individual Single-Cell RNA-seq PBMC Data from ...    Human        blood
# 9  All - A single-cell transcriptomic atlas chara...    Mouse   22 tissues
#
#                Disease                  Assay    Organism.1      Cells  \
# 0               normal               3 assays  Homo sapiens    347 970
# 1  normal -15 diseases               8 assays  Homo sapiens  2 282 447
# 2               normal               4 assays  Homo sapiens    592 317
# 3               normal  10x 3' v3, Smart-seq2  Homo sapiens      2 685
# 4               normal               3 assays  Homo sapiens     85 233
# 5               normal               3 assays  Homo sapiens     27 112
# 6               normal  10x 3' v3, Smart-seq2  Homo sapiens     22 214
# 7               normal  10x 3' v3, Smart-seq2  Homo sapiens     17 786
# 8     normal, COVID-19              10x 3' v3  Homo sapiens     43 512
# 9               normal             Smart-seq2  Mus musculus    110 824
#
#                                             Download   Size
# 0  https://datasets.cellxgene.cziscience.com/8b45...    4Gb
# 1  https://datasets.cellxgene.cziscience.com/dbb5...   20Gb
# 2  https://datasets.cellxgene.cziscience.com/e62b...   18Gb
# 3  https://datasets.cellxgene.cziscience.com/157a...  122Mb
# 4  https://datasets.cellxgene.cziscience.com/b225...    2Gb
# 5  https://datasets.cellxgene.cziscience.com/c7f0...  983Mb
# 6  https://datasets.cellxgene.cziscience.com/62e4...  796Mb
# 7  https://datasets.cellxgene.cziscience.com/c4fb...  485Mb
# 8  https://datasets.cellxgene.cziscience.com/c26a...  413Mb
# 9  https://datasets.cellxgene.cziscience.com/6fe2...    2Gb

# %%
df.iloc[0, 7]
# Out:
# 'https://datasets.cellxgene.cziscience.com/8b459307-bce0-45f9-9e45-a0a3673058a2.h5ad'

# %%
ad1 = sc.read_h5ad("/data/analysis/data_ganguly/blood.h5ad")
ad1
# Out:
# AnnData object with n_obs × n_vars = 85233 × 60606
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_tissue', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'compartment_colors', 'donor_id_colors', 'leiden', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_tissue_uncorrected_umap', 'X_umap', 'X_umap_scvi_full_donorassay', 'X_umap_tissue_scvi_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'

# %%
ad1.obs.scvi_leiden_donorassay_full.unique()
# Out:
# ['33', '34', '21', '8', '1', ..., '45', '5', '37', '23', '54']
# Length: 25
# Categories (25, object): ['1', '2', '3', '4', ..., '45', '48', '53', '54']

# %%
ad1.obs.cell_type.unique()
# Out:
# ['monocyte', 'mature NK T cell', 'platelet', 'plasma cell', 'CD4-positive, alpha-beta T cell', ..., 'macrophage', 'intermediate monocyte', 'plasmacytoid dendritic cell', 'basophil', 'common myeloid progenitor']
# Length: 22
# Categories (22, object): ['hematopoietic stem cell', 'common myeloid progenitor', 'erythrocyte', 'platelet', ..., 'non-classical monocyte', 'naive thymus-derived CD4-positive, alpha-beta..., 'intermediate monocyte', 'hematopoietic precursor cell']

# %%
ad1.obs.filter(like='cell')
# Out:
#                                    cell_type_ontology_term_id celltype_level1  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                 CL:0000313          Serous
# Donor27_Donor27_AAAGAACAGCGCCATC-1                 CL:0000313          Serous
# Donor27_Donor27_AAAGAACCAGGCAATG-1                 CL:0000313          Serous
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                 CL:0009086             LEC
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                 CL:0000794               T
# ...                                                       ...             ...
# TCTCACGTCTAACACG-1_7                               CL:4028004             AF1
# AGGGTGAAGGGCTGAT-1_7                               CL:0000912               T
# AACGTCAGTGACTATC-1_7                               CL:0000786               B
# CGTGCTTCAAGGTCGA-1_7                               CL:0002062             AT1
# TGCTCGTGTCACGTGC-1_7                               CL:4033043              IM
#
#                                    celltype_level2 celltype_level3  \
# Donor27_Donor27_AAACGAACACCGTGCA-1          Serous          Serous
# Donor27_Donor27_AAAGAACAGCGCCATC-1          Serous          Serous
# Donor27_Donor27_AAAGAACCAGGCAATG-1          Serous          Serous
# Donor27_Donor27_AAAGGATAGTAGCTCT-1             LEC             LEC
# Donor27_Donor27_AAAGTCCCATCCGGCA-1           CD8 T           CD8 T
# ...                                            ...             ...
# TCTCACGTCTAACACG-1_7                           AF1             AF1
# AGGGTGAAGGGCTGAT-1_7                         CD4 T           CD4 T
# AACGTCAGTGACTATC-1_7                        Plasma          Plasma
# CGTGCTTCAAGGTCGA-1_7                           AT1             AT1
# TGCTCGTGTCACGTGC-1_7                            IM              IM
#
#                                       celltype_level3_fullname  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                 Serous cell
# Donor27_Donor27_AAAGAACAGCGCCATC-1                 Serous cell
# Donor27_Donor27_AAAGAACCAGGCAATG-1                 Serous cell
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  Lymphatic endothelial cell
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                 CD8+ T cell
# ...                                                        ...
# TCTCACGTCTAACACG-1_7                     Alveolar fibroblast 1
# AGGGTGAAGGGCTGAT-1_7                               CD4+ T cell
# AACGTCAGTGACTATC-1_7                               Plasma cell
# CGTGCTTCAAGGTCGA-1_7                      Alveolar type 1 cell
# TGCTCGTGTCACGTGC-1_7                   Interstitial macrophage
#
#                                                                             cell_type
# Donor27_Donor27_AAACGAACACCGTGCA-1                              serous secreting cell
# Donor27_Donor27_AAAGAACAGCGCCATC-1                              serous secreting cell
# Donor27_Donor27_AAAGAACCAGGCAATG-1                              serous secreting cell
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  endothelial cell of respiratory system lymphat...
# Donor27_Donor27_AAAGTCCCATCCGGCA-1          CD8-positive, alpha-beta cytotoxic T cell
# ...                                                                               ...
# TCTCACGTCTAACACG-1_7                                  alveolar type 1 fibroblast cell
# AGGGTGAAGGGCTGAT-1_7                                                    helper T cell
# AACGTCAGTGACTATC-1_7                                                      plasma cell
# CGTGCTTCAAGGTCGA-1_7                                   pulmonary alveolar type 1 cell
# TGCTCGTGTCACGTGC-1_7                                     lung interstitial macrophage
#
# [347970 rows x 6 columns]

# %%
list(ad1.obs.celltype_level3.unique())
# Out:
# ['Serous',
#  'LEC',
#  'CD8 T',
#  'Mucous',
#  'SVEC',
#  'SMG Basal/Duct',
#  'IM',
#  'Goblet',
#  'MEC',
#  'Treg',
#  'NK',
#  'CD4 T',
#  'Secretory',
#  'Ionocyte',
#  'VSMC',
#  'B',
#  'Neutrophil',
#  'AF2',
#  'pMON',
#  'Plasma',
#  'Ciliated',
#  'cDC2',
#  'Suprabasal',
#  'AEC',
#  'Basal',
#  'AM',
#  'Pericyte',
#  'AT2',
#  'VEC',
#  'ASMC',
#  'ILC',
#  'iMON',
#  'Mast/Basophil',
#  'SCMF',
#  'Deuterosomal',
#  'AF1',
#  'Tuft',
#  'cDC1',
#  'PNEC',
#  'Chondrocyte',
#  'pDC',
#  'maDC',
#  'AT1',
#  'RAS',
#  'CAP1',
#  'CAP2',
#  'Mesothelial',
#  'Megakaryocyte/Platelet']

# %%
list(ad1.obs.cell_type.unique())
# Out:
# ['serous secreting cell',
#  'endothelial cell of respiratory system lymphatic vessel',
#  'CD8-positive, alpha-beta cytotoxic T cell',
#  'mucus secreting cell of tracheobronchial tree submucosal gland',
#  'vein endothelial cell of respiratory system',
#  'airway submucosal gland collecting duct epithelial cell',
#  'lung interstitial macrophage',
#  'goblet cell',
#  'myoepithelial cell',
#  'regulatory T cell',
#  'natural killer cell',
#  'helper T cell',
#  'secretory cell',
#  'ionocyte',
#  'vascular associated smooth muscle cell',
#  'B cell',
#  'neutrophil',
#  'alveolar adventitial fibroblast',
#  'non-classical monocyte',
#  'plasma cell',
#  'ciliated cell',
#  'conventional dendritic cell',
#  'respiratory tract suprabasal cell',
#  'endothelial cell of artery',
#  'basal cell',
#  'alveolar macrophage',
#  'pericyte',
#  'pulmonary alveolar type 2 cell',
#  'vein endothelial cell',
#  'tracheobronchial smooth muscle cell',
#  'innate lymphoid cell',
#  'classical monocyte',
#  'mast cell',
#  'secondary crest myofibroblast',
#  'deuterosomal cell',
#  'alveolar type 1 fibroblast cell',
#  'brush cell of tracheobronchial tree',
#  'pulmonary neuroendocrine cell',
#  'chondrocyte',
#  'plasmacytoid dendritic cell',
#  'mature conventional dendritic cell',
#  'pulmonary alveolar type 1 cell',
#  'lung secretory cell',
#  'alveolar capillary type 1 endothelial cell',
#  'alveolar capillary type 2 endothelial cell',
#  'mesothelial cell of pleura',
#  'lung megakaryocyte']

# %%
ad1.obs.cell_type.nunique()
# Out:
# 47
